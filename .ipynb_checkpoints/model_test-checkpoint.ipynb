# %%
pip uninstall torch torchvision torchaudio

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in c:\users\mahdi\appdata\local\programs\python\python310\lib\site-packages (1.13.0)
# Requirement already satisfied: torchvision in c:\users\mahdi\appdata\local\programs\python\python310\lib\site-packages (0.14.0)
# Requirement already satisfied: torchaudio in c:\users\mahdi\appdata\local\programs\python\python310\lib\site-packages (0.13.0+cu117)
# Requirement already satisfied: typing-extensions in c:\users\mahdi\appdata\local\programs\python\python310\lib\site-packages (from torch) (4.4.0)
# Requirement already satisfied: numpy in c:\users\mahdi\appdata\local\programs\python\python310\lib\site-packages (from torchvision) (1.25.1)
# Requirement already satisfied: requests in c:\users\mahdi\appdata\local\programs\python\python310\lib\site-packages (from torchvision) (2.28.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\mahdi\appdata\local\programs\python\python310\lib\site-packages (from torchvision) (8.4.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\mahdi\appdata\local\programs\python\python310\lib\site-packages (from requests->torchvision) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mahdi\appdata\local\programs\python\python310\lib\site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mahdi\appdata\local\programs\python\python310\lib\site-packages (from requests->torchvision) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mahdi\appdata\local\programs\python\python310\lib\site-packages (from requests->torchvision) (2022.12.7)

# %%
import torch

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='./best.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\Mahdi/.cache\torch\hub\master.zip
# YOLOv5  2023-8-31 Python-3.10.0 torch-1.13.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7061368 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
from ultralytics import YOLO

# %%
# !pip show torch
# Out:
# Name: torch
# Version: 1.13.0
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3
# Location: c:\users\mahdi\appdata\local\programs\python\python310\lib\site-packages
# Requires: typing-extensions
# Required-by: sentence-transformers, thop, torchaudio, torchvision, ultralytics

# %%
# !cd ./yolov5 && python detect.py --source  --weights /content/yolov5/runs/train/exp2/weights/last.pt --img-size 320 --conf 0.4

# %%
result = model(image)

# %%
result.print()
# Out:
# image 1/1: 427x700 1 50dt
# Speed: 487.3ms pre-process, 574.6ms inference, 212.3ms NMS per image at shape (1, 3, 416, 640)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline
plt.figure(figsize=(12,8))
plt.imshow(np.squeeze(result.render()))
plt.show()
